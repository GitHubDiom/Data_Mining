# %%
import pandas as pd

data_filename = './NBA_Data.csv'
dataset = pd.read_csv(data_filename,parse_dates = ['Date'])
dataset.columns = ["Date", "Start (ET)", "Visitor Team", "VisitorPts", "Home Team", "HomePts",  "Score Type","OT?","Attend","Notes"]
dataset = dataset.sort_values('Date',ascending = True , axis=0)
dataset.head()
# Out:
#          Date Start (ET)          Visitor Team  VisitorPts  \
# 0  2013-10-29    7:00 pm         Orlando Magic          87
# 1  2013-10-29   10:30 pm  Los Angeles Clippers         103
# 2  2013-10-29    8:00 pm         Chicago Bulls          95
# 15 2013-10-30    7:00 pm        Boston Celtics          87
# 14 2013-10-30    8:30 pm     Memphis Grizzlies          94
#
#              Home Team  HomePts Score Type  OT?  Attend Notes
# 0       Indiana Pacers       97  Box Score  NaN   18165   NaN
# 1   Los Angeles Lakers      116  Box Score  NaN   18997   NaN
# 2           Miami Heat      107  Box Score  NaN   19964   NaN
# 15     Toronto Raptors       93  Box Score  NaN   20155   NaN
# 14   San Antonio Spurs      101  Box Score  NaN   18581   NaN

# %%
dataset['Homewin'] = dataset['HomePts']>dataset['VisitorPts']
Home_win = dataset['Homewin'].values

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import cross_val_score
import numpy as np
from collections import defaultdict
dataset["HomeLastWin"] = False
dataset["VisitorLastWin"] = False
# Out:
# e:\python36\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
won_in_last_game = defaultdict(bool)
for index , row in dataset.iterrows():
    visitor_team = row['Visitor Team']
    home_team = row['Home Team']
    #won_in_last_game初始化为false ，即在df中第一次出现的队伍主客场战绩都会被标记为False
    dataset.at[index , "VisitorLastWin"] = won_in_last_game[visitor_team]
    dataset.at[index , "HomeLastWin"] = won_in_last_game[home_team]
    #每次更新本次主场的胜负作为下一次遍历时的“上一场战绩”，主队胜则客队败
    won_in_last_game[home_team] = row['Homewin']
    won_in_last_game[visitor_team] = not row['Homewin']
Y_true = dataset['Homewin']
#dataset[(dataset['Home Team']=='San Antonio Spurs')|(dataset['Visitor Team']=='San Antonio Spurs')]
#dataset.loc[20:25]

# %%
X_d = dataset[['VisitorLastWin','HomeLastWin']].values
clf = DecisionTreeClassifier(random_state =14)
scores = cross_val_score(clf , X_d , Y_true , scoring = 'accuracy')
np.mean(scores)*100
# Out:
# 57.54365983295367

# %%
standing_file = './NBA_2013_Standings.csv'
standings = pd.read_csv(standing_file)
'''利用对阵队伍排名与上赛季最终排名比较得出HomeTeamRanksHeigher'''
dataset['HomeTeamRanksHeigher'] = 0

# %%
for index , row in dataset.iterrows():
    home_team = row['Home Team']
    visitor_team = row['Visitor Team']
    home_rank = standings[standings['Team']==home_team]['Rk'].values[0]
    visitor_rank = standings[standings['Team']==visitor_team]['Rk'].values[0]
    dataset.at[index , "HomeTeamRanksHeigher"] = int(home_rank < visitor_rank)

# %%
X_d = dataset[['HomeTeamRanksHeigher','VisitorLastWin','HomeLastWin']].values
clf = DecisionTreeClassifier(random_state =14)
scores = cross_val_score(clf , X_d , Y_true , scoring = 'accuracy')
np.mean(scores)*100
# Out:
# 67.0197418375095

# %%
last_match_winner = defaultdict(int)
row['HomeTeamWonLast'] = 0
teams_list = set()
"""找到两支队伍上次交锋情况 ， 不考虑主客队"""
for index , row in dataset.iterrows():
    home_team = row['Home Team']
    visitor_team = row['Visitor Team']
    teams = tuple(sorted([home_team , visitor_team]))
    teams_list.add(teams)
    dataset.at[index , "HomeTeamWonLast"] = 1 if last_match_winner[teams] == home_team else 0
    last_match_winner[teams] = home_team if row['Homewin'] else visitor_team
dataset.loc[400:500]
# Out:
#           Date Start (ET)            Visitor Team  VisitorPts  \
# 400 2013-12-21   10:00 pm    New Orleans Pelicans         107
# 399 2013-12-21    9:00 pm        Dallas Mavericks         108
# 398 2013-12-21    7:00 pm        Sacramento Kings         105
# 396 2013-12-21    8:30 pm      Philadelphia 76ers         106
# 391 2013-12-21    7:30 pm               Utah Jazz          88
# 394 2013-12-21   10:30 pm      Los Angeles Lakers          83
# 393 2013-12-21    7:30 pm         Houston Rockets         114
# 392 2013-12-21    8:00 pm     Cleveland Cavaliers          84
# 390 2013-12-21    1:00 pm      Washington Wizards         106
# 395 2013-12-21   10:30 pm          Denver Nuggets          91
# 404 2013-12-22    7:00 pm         Toronto Raptors         104
# 402 2013-12-22    6:00 pm          Boston Celtics          79
# 403 2013-12-22    9:30 pm  Minnesota Timberwolves         116
# 413 2013-12-23    9:00 pm      Los Angeles Lakers          90
# 411 2013-12-23    7:30 pm           Atlanta Hawks         119
# 415 2013-12-23    8:30 pm         Toronto Raptors          99
# 414 2013-12-23   10:00 pm    New Orleans Pelicans         113
# 410 2013-12-23    8:00 pm               Utah Jazz          94
# 412 2013-12-23    7:00 pm         New York Knicks         103
# 408 2013-12-23    9:00 pm   Golden State Warriors          89
# 409 2013-12-23    8:00 pm        Dallas Mavericks         111
# 407 2013-12-23    7:00 pm         Detroit Pistons         115
# 406 2013-12-23    7:00 pm         Milwaukee Bucks         110
# 405 2013-12-23    7:30 pm          Indiana Pacers         103
# 420 2013-12-25    8:00 pm         Houston Rockets         111
# 418 2013-12-25    5:00 pm              Miami Heat         101
# 419 2013-12-25    2:30 pm   Oklahoma City Thunder         123
# 416 2013-12-25   12:00 am           Chicago Bulls          95
# 417 2013-12-25   10:30 pm    Los Angeles Clippers         103
# 421 2013-12-26    7:00 pm           Atlanta Hawks         127
# ..         ...        ...                     ...         ...
# 469 2014-01-01    7:00 pm          Indiana Pacers          82
# 466 2014-01-01    9:00 pm      Philadelphia 76ers         114
# 467 2014-01-01    9:30 pm       Charlotte Bobcats          85
# 478 2014-01-02    8:30 pm         New York Knicks         105
# 477 2014-01-02   10:00 pm      Philadelphia 76ers         113
# 476 2014-01-02   10:00 pm       Charlotte Bobcats         104
# 475 2014-01-02    9:00 pm       Memphis Grizzlies          99
# 479 2014-01-02    9:00 pm         Milwaukee Bucks          87
# 473 2014-01-02    7:30 pm   Golden State Warriors         123
# 472 2014-01-02    7:00 pm           Orlando Magic          81
# 471 2014-01-02    8:00 pm          Boston Celtics          82
# 474 2014-01-02    8:00 pm           Brooklyn Nets          95
# 480 2014-01-03    7:30 pm   Golden State Warriors         101
# 481 2014-01-03    7:30 pm    New Orleans Pelicans          95
# 482 2014-01-03    8:30 pm    Los Angeles Clippers         119
# 483 2014-01-03    9:00 pm       Memphis Grizzlies         108
# 484 2014-01-03    8:00 pm         New York Knicks         100
# 485 2014-01-03   10:30 pm               Utah Jazz          99
# 486 2014-01-03    7:00 pm         Toronto Raptors         101
# 492 2014-01-04    9:00 pm         Milwaukee Bucks         100
# 495 2014-01-04    8:30 pm    Los Angeles Clippers          92
# 493 2014-01-04   10:00 pm      Philadelphia 76ers         101
# 491 2014-01-04    7:00 pm              Miami Heat         110
# 494 2014-01-04   10:00 pm       Charlotte Bobcats         113
# 489 2014-01-04    7:00 pm    New Orleans Pelicans          82
# 488 2014-01-04    8:00 pm           Atlanta Hawks          84
# 487 2014-01-04    7:30 pm     Cleveland Cavaliers          82
# 490 2014-01-04    8:00 pm   Oklahoma City Thunder         115
# 502 2014-01-05    6:00 pm   Golden State Warriors         112
# 500 2014-01-05    6:00 pm         Toronto Raptors          97
#
#                   Home Team  HomePts Score Type  OT?  Attend Notes  Homewin  \
# 400  Portland Trail Blazers      110  Box Score  NaN   20027   NaN     True
# 399            Phoenix Suns      123  Box Score  NaN   15241   NaN     True
# 398           Orlando Magic      100  Box Score  NaN   14283   NaN    False
# 396         Milwaukee Bucks      116  Box Score  NaN   14541   NaN     True
# 391       Charlotte Bobcats       85  Box Score  NaN   18078   NaN    False
# 394   Golden State Warriors      102  Box Score  NaN   19596   NaN     True
# 393         Detroit Pistons       97  Box Score  NaN   14606   NaN    False
# 392           Chicago Bulls      100  Box Score  NaN   21658   NaN     True
# 390          Boston Celtics       99  Box Score  NaN   18169   NaN    False
# 395    Los Angeles Clippers      112  Box Score  NaN   19129   NaN     True
# 404   Oklahoma City Thunder       98  Box Score  NaN   18203   NaN    False
# 402          Indiana Pacers      106  Box Score  NaN   18165   NaN     True
# 403    Los Angeles Clippers      120  Box Score   OT   19304   NaN     True
# 413            Phoenix Suns      117  Box Score  NaN   14814   NaN     True
# 411              Miami Heat      121  Box Score   OT   20204   NaN     True
# 415       San Antonio Spurs      112  Box Score  NaN   18581   NaN     True
# 414        Sacramento Kings      100  Box Score  NaN   17317   NaN    False
# 410       Memphis Grizzlies      104  Box Score  NaN   16665   NaN     True
# 412           Orlando Magic       98  Box Score  NaN   15105   NaN    False
# 408          Denver Nuggets       81  Box Score  NaN   18551   NaN    False
# 409         Houston Rockets      104  Box Score  NaN   18328   NaN    False
# 407     Cleveland Cavaliers       92  Box Score  NaN   19215   NaN    False
# 406       Charlotte Bobcats      111  Box Score   OT   13534   NaN     True
# 405           Brooklyn Nets       86  Box Score  NaN   17732   NaN    False
# 420       San Antonio Spurs       98  Box Score  NaN   18581   NaN    False
# 418      Los Angeles Lakers       95  Box Score  NaN   18997   NaN    False
# 419         New York Knicks       94  Box Score  NaN   19812   NaN    False
# 416           Brooklyn Nets       78  Box Score  NaN   17732   NaN    False
# 417   Golden State Warriors      105  Box Score  NaN   19596   NaN     True
# 421     Cleveland Cavaliers      125  Box Score  2OT   18682   NaN    False
# ..                      ...      ...        ...  ...     ...   ...      ...
# 469         Toronto Raptors       95  Box Score  NaN   18271   NaN     True
# 466          Denver Nuggets      102  Box Score  NaN   16006   NaN    False
# 467    Los Angeles Clippers      112  Box Score  NaN   19160   NaN     True
# 478       San Antonio Spurs      101  Box Score  NaN   18581   NaN    False
# 477        Sacramento Kings      104  Box Score  NaN   16259   NaN    False
# 476  Portland Trail Blazers      134  Box Score  NaN   20014   NaN     True
# 475            Phoenix Suns       91  Box Score  NaN   14844   NaN    False
# 479               Utah Jazz       96  Box Score  NaN   16012   NaN     True
# 473              Miami Heat      114  Box Score  NaN   20350   NaN    False
# 472     Cleveland Cavaliers       87  Box Score   OT   14248   NaN     True
# 471           Chicago Bulls       94  Box Score  NaN   21721   NaN     True
# 474   Oklahoma City Thunder       93  Box Score  NaN   18203   NaN    False
# 480           Atlanta Hawks      100  Box Score  NaN   15210   NaN    False
# 481          Boston Celtics       92  Box Score  NaN   18624   NaN    False
# 482        Dallas Mavericks      112  Box Score  NaN   20187   NaN    False
# 483          Denver Nuggets      111  Box Score  NaN   17608   NaN     True
# 484         Houston Rockets      102  Box Score  NaN   18304   NaN     True
# 485      Los Angeles Lakers      110  Box Score  NaN   18997   NaN     True
# 486      Washington Wizards       88  Box Score  NaN   14940   NaN    False
# 492            Phoenix Suns      116  Box Score  NaN   14344   NaN     True
# 495       San Antonio Spurs      116  Box Score  NaN   18581   NaN     True
# 493  Portland Trail Blazers       99  Box Score  NaN   20004   NaN    False
# 491           Orlando Magic       94  Box Score  NaN   18846   NaN    False
# 494        Sacramento Kings      103  Box Score  NaN   16410   NaN    False
# 489          Indiana Pacers       99  Box Score  NaN   18165   NaN     True
# 488           Chicago Bulls       91  Box Score  NaN   21539   NaN     True
# 487           Brooklyn Nets       89  Box Score  NaN   17732   NaN     True
# 490  Minnesota Timberwolves      111  Box Score  NaN   18065   NaN    False
# 502      Washington Wizards       96  Box Score  NaN   17390   NaN    False
# 500              Miami Heat      102  Box Score  NaN   20020   NaN     True
#
#      HomeLastWin  VisitorLastWin  HomeTeamRanksHeigher  HomeTeamWonLast
# 400        False           False                     1              0.0
# 399         True           False                     0              0.0
# 398        False           False                     0              0.0
# 396        False            True                     0              0.0
# 391         True           False                     1              0.0
# 394        False            True                     1              0.0
# 393        False           False                     0              0.0
# 392        False            True                     1              0.0
# 390        False            True                     0              0.0
# 395         True           False                     1              0.0
# 404         True            True                     1              0.0
# 402         True           False                     1              1.0
# 403         True           False                     1              1.0
# 413         True           False                     1              1.0
# 411         True            True                     1              1.0
# 415        False            True                     1              1.0
# 414         True           False                     0              0.0
# 410         True            True                     1              0.0
# 412        False           False                     0              0.0
# 408        False            True                     0              0.0
# 409         True           False                     1              0.0
# 407        False           False                     1              0.0
# 406        False            True                     1              1.0
# 405        False            True                     0              0.0
# 420         True           False                     1              0.0
# 418        False            True                     0              0.0
# 419         True           False                     0              0.0
# 416        False            True                     0              0.0
# 417         True            True                     0              0.0
# 421        False           False                     0              0.0
# ..           ...             ...                   ...              ...
# 469         True            True                     0              0.0
# 466        False            True                     1              1.0
# 467        False           False                     1              0.0
# 478         True           False                     1              1.0
# 477         True            True                     1              0.0
# 476         True           False                     1              0.0
# 475         True           False                     0              0.0
# 479         True            True                     1              0.0
# 473         True            True                     1              0.0
# 472        False           False                     1              1.0
# 471        False           False                     1              0.0
# 474        False           False                     1              0.0
# 480         True            True                     0              0.0
# 481        False           False                     0              0.0
# 482         True            True                     0              0.0
# 483        False            True                     0              0.0
# 484        False            True                     1              1.0
# 485        False            True                     1              0.0
# 486        False            True                     0              0.0
# 492        False           False                     1              0.0
# 495        False            True                     1              0.0
# 493         True            True                     1              1.0
# 491        False           False                     0              0.0
# 494        False           False                     0              0.0
# 489        False            True                     1              1.0
# 488         True           False                     1              0.0
# 487         True            True                     1              0.0
# 490         True           False                     0              0.0
# 502        False            True                     0              0.0
# 500         True            True                     1              1.0
#
# [106 rows x 15 columns]

# %%
TX_d = dataset[['HomeTeamWonLast','HomeTeamRanksHeigher','VisitorLastWin','HomeLastWin']].values
clf = DecisionTreeClassifier(random_state =14)
scores = cross_val_score(clf , X_d , Y_true , scoring = 'accuracy')
np.mean(scores)*100
# Out:
# 67.0197418375095

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
encoding = LabelEncoder()
encoding.fit(dataset['Home Team'].values)#将dataset['Home Team']里的所有队伍标记成0到dataset['Home Team'].unique()-1的序号，即数值型属性
home_teams = encoding.transform(dataset['Home Team'].values)
visitor_teams = encoding.transform(dataset['Visitor Team'].values)
teams = np.vstack([visitor_teams , home_teams]).T#vertical stacking
#teams = np.hstack([visitor_teams , home_teams])
teams
# Out:
# array([[21, 11],
#        [12, 13],
#        [ 4, 15],
#        ...,
#        [26, 15],
#        [26, 15],
#        [15, 26]], dtype=int64)

# %%
'''进行one_hot 编码需要先属性型（字符串）特征进行数值转化，后通过转化后的数值属性进行编码'''
onehot = OneHotEncoder()
X_teams = onehot.fit_transform(teams).todense()
clf = DecisionTreeClassifier(random_state=14)
scores = cross_val_score(clf , X_teams , Y_true,  scoring = 'accuracy')
np.mean(scores)*100
# Out:
# 59.21222475322702

# %%
from sklearn.ensemble import RandomForestClassifier
X_all = np.hstack([X_teams , X_d])#herizontal stacking
clf = RandomForestClassifier(random_state=14)
scores = cross_val_score(clf,X_all , Y_true , scoring = 'accuracy')
np.mean(scores)*100
# Out:
# 61.790915993649485

# %%
from sklearn.model_selection import GridSearchCV
parameter = {
    "max_features" : [2,10, 'auto'],
    "n_estimators" : [100,],
    "criterion" : ["gini" , 'entropy'],
    "min_samples_leaf" : [2,4,6]
}
'''按照以上parameter的参数遍历搜索，找到一组最佳参数'''
clf = RandomForestClassifier(random_state=14)
grid = GridSearchCV(clf , parameter)
grid.fit(X_all , Y_true)
print(type(grid))
#print(grid.best_score_*100)
# Out:
# <class 'sklearn.model_selection._search.GridSearchCV'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-32917e82fff3> in <module>()
# ----> 1 dataset['New Feature'] = feature_creator(dataset)
#       2 dataset['New Feature']
#
# NameError: name 'feature_creator' is not defined
